# %%
import geopandas

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
A=[1,2,3,4,5]
B=np.array([1,2,3,4,5])
plt.scatter(A,B)

# %%
import leafmap

# %%
m=leafmap.Map(Hybrid=True)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
